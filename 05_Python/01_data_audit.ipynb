# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import os
print(os.getcwd())

# %%
import os

print(os.listdir(".."))

# %%
customer=pd.read_csv("../02_raw_data/customers.csv")
order_items=pd.read_csv("../02_raw_data/order_line_items.csv")
orders=pd.read_csv("../02_raw_data/orders.csv")
catalog=pd.read_csv("../02_raw_data/sku_catalog.csv")
sessions=pd.read_csv("../02_raw_data/website_sessions.csv")

# %% [markdown]
# ## Data Inventory ##
# In this step, we inspect the size of each dataset to understand the amount of data available for analysis.

# %%
customer.shape

# %%
orders.shape

# %%
order_items.shape

# %%
catalog.shape

# %%
sessions.shape

# %% [markdown]
# ## Understanding the Columns
#
# In this step, we inspect the columns of each table to understand what business information each dataset contains.

# %%
customer.columns

# %%
customer.sample(10)

# %%
orders.columns

# %%
orders.sample(5)

# %%
order_items.columns

# %%
order_items.sample(5)

# %%
catalog.columns

# %%
catalog.head(10)

# %%
sessions.columns

# %%
sessions.sample(10)

# %% [markdown]
# ## Data Types
#
# In this step, we inspect the data types of each column to identify whether they are stored correctly for analysis.

# %%
customer.info()
orders.info()
order_items.info()
catalog.info()
sessions.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16865 entries, 0 to 16864
# Data columns (total 11 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   Customer ID                        16865 non-null  object
#  1   Name                               16865 non-null  object
#  2   First order date                   16865 non-null  datetime64[ns]
#  3   Total orders                       16865 non-null  int64
#  4   Total revenue                      16865 non-null  float64
#  5   Average order value                16865 non-null  float64
#  6   Time to 2nd purchase               7748 non-null   float64
#  7   Last purchase date                 16865 non-null  datetime64[ns]
#  8   City / tier                        16865 non-null  object
#  9   Acquisition channel (first touch)  16865 non-null  object
#  10  RePurchased                        16865 non-null  object
# dtypes: datetime64[ns](2), float64(3), int64(1), object(5)
# memory usage: 1.4+ MB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30000 entries, 0 to 29999
# Data columns (total 16 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Order ID                     30000 non-null  object
#  1   Customer ID                  30000 non-null  object
#  2   Order date & time            30000 non-null  datetime64[ns]
#  3   Product                      30000 non-null  object
#  4   Order value (gross, net)     30000 non-null  object
#  5   Order value (gross)          30000 non-null  int64
#  6   Order value (net)            30000 non-null  int64
#  7   Discount applied (₹ + %)     30000 non-null  object
#  8   Discount applied (₹)         30000 non-null  int64
#  9   Discount applied (%)         30000 non-null  float64
#  10  Payment mode                 30000 non-null  object
#  11  Shipping city                30000 non-null  object
#  12  Pincode                      30000 non-null  int64
#  13  First order vs repeat        30000 non-null  object
#  14  Channel source (last touch)  30000 non-null  object
#  15  Delivered / Returned / RTO   30000 non-null  object
# dtypes: datetime64[ns](1), float64(1), int64(4), object(10)
# memory usage: 3.7+ MB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 42121 entries, 0 to 42120
# Data columns (total 10 columns):
#  #   Column                                   Non-Null Count  Dtype
# ---  ------                                   --------------  -----
#  0   Order ID                                 42121 non-null  object
#  1   SKU ID                                   42121 non-null  object
#  2   Category (top, bottom, outerwear, etc.)  42121 non-null  object
#  3   Size                                     42121 non-null  object
#  4   Color                                    42121 non-null  object
#  5   MRP                                      42121 non-null  int64
#  6   Selling price                            42121 non-null  int64
#  7   Discount %                               42121 non-null  float64
#  8   Returned? (Y/N)                          42121 non-null  object
#  9   Return reason (if any)                   14877 non-null  object
# dtypes: float64(1), int64(2), object(7)
# memory usage: 3.2+ MB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 55 entries, 0 to 54
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   SKU            55 non-null     object
#  1   Category       55 non-null     object
#  2   Vendor         55 non-null     object
#  3   MRP            55 non-null     int64
#  4   Cost_per_unit  55 non-null     int64
# dtypes: int64(2), object(3)
# memory usage: 2.3+ KB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 475658 entries, 0 to 475657
# Data columns (total 14 columns):
#  #   Column           Non-Null Count   Dtype
# ---  ------           --------------   -----
#  0   session_id       475658 non-null  object
#  1   date             475658 non-null  datetime64[ns]
#  2   traffic_source   475658 non-null  object
#  3   campaign_name    228192 non-null  object
#  4   device_category  475658 non-null  object
#  5   city             475658 non-null  object
#  6   sessions         475658 non-null  int64
#  7   product_views    475658 non-null  int64
#  8   add_to_cart      475658 non-null  int64
#  9   begin_checkout   475658 non-null  int64
#  10  purchased        475658 non-null  int64
#  11  order_id         24764 non-null   object
#  12  customer_id      24764 non-null   object
#  13  revenue          475658 non-null  int64
# dtypes: datetime64[ns](1), int64(6), object(7)
# memory usage: 50.8+ MB

# %% [markdown]
# ## Missing Value Analysis
#
# In this step, we identify missing values in each table to understand data completeness and determine whether the missing values are valid business cases or data quality issues.

# %%
customer.isnull().sum().sort_values(ascending=False)

# %%
orders.isnull().sum().sort_values(ascending=False)

# %%
order_items.isnull().sum().sort_values(ascending=False)

# %%
catalog.isnull().sum().sort_values(ascending=False)

# %%
sessions.isnull().sum().sort_values(ascending=False)

# %% [markdown]
# ## Data type fix
# in this step, we will fix the dates column to data type date and other numeric values to float or int

# %%
customer['First order date']=pd.to_datetime(customer['First order date'])

# %%
orders["Order date & time"]=pd.to_datetime(orders["Order date & time"])

# %%
orders["Discount applied (%)"]=(orders["Discount applied (%)"].str.replace("%","").astype(float))

# %%
customer['Last purchase date']=pd.to_datetime(customer['Last purchase date'])

# %%
sessions["date"]=pd.to_datetime(sessions["date"],dayfirst="True")

# %%
sessions.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 475658 entries, 0 to 475657
# Data columns (total 14 columns):
#  #   Column           Non-Null Count   Dtype
# ---  ------           --------------   -----
#  0   session_id       475658 non-null  object
#  1   date             475658 non-null  datetime64[ns]
#  2   traffic_source   475658 non-null  object
#  3   campaign_name    228192 non-null  object
#  4   device_category  475658 non-null  object
#  5   city             475658 non-null  object
#  6   sessions         475658 non-null  int64
#  7   product_views    475658 non-null  int64
#  8   add_to_cart      475658 non-null  int64
#  9   begin_checkout   475658 non-null  int64
#  10  purchased        475658 non-null  int64
#  11  order_id         24764 non-null   object
#  12  customer_id      24764 non-null   object
#  13  revenue          475658 non-null  int64
# dtypes: datetime64[ns](1), int64(6), object(7)
# memory usage: 50.8+ MB
